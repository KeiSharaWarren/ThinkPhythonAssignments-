# %% [markdown]
# <a href="https://colab.research.google.com/github/KeiSharaWarren/ThinkPhythonAssignments-/blob/main/Midterm_Project/Midterm_Project.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# NAME: rentalcar.py

# FUNCTION DEFINITONS

# get_classification_name(code)
#   return full car type name based on, B, S, or L

# get_daily_rate(code)
    return daily rental rate based on classification code

#calculate_charged_miles(total_miles)
#  if total miles is over 100
#     charged miles = total miles - 100
#  otherwise
#      charged miles = 0
#  return charged miles

# calculate_total_bill(code, days_rented, charged miles)
# get daily rate
# day charge = daily rate times number of days
# mileage charge = charged miles time 0.35
# total bill = day charge + mileage charge
# return total bill

#PROGRAM LOGIC
# ask user for classification code
# validate code until it is B, S, or L
# ask for start odemeter
# ask for end odemeter
# ask for days rented
# calcualte total miles
# calculate charged miles
#calcualte total bill
#display rental summary
