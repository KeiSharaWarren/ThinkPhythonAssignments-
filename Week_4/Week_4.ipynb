# %% [markdown]
# <a href="https://colab.research.google.com/github/KeiSharaWarren/ThinkPhythonAssignments-/blob/main/Week_4/Week_4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Import Statements

# Function Definitions
# Define print_bio with three parameters: name, age and goal
# Inside the function, use string multipication (*) for a border line
# Print the bio details using parameter names.

# Program Logic
# Call print_bio using my own info(Name of famous person)
# Call print_bio using (Name of Fictional Character)
