# %% [markdown]
# <a href="https://colab.research.google.com/github/KeiSharaWarren/ThinkPhythonAssignments-/blob/main/week/1CourseSetup.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print(3*3)

my_name =input("give me a name:")
print(my_name)
# Out:
# 9
# give me a name:Jane Doe
# Jane Doe
