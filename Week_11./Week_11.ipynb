# %% [markdown]
# <a href="https://colab.research.google.com/github/KeiSharaWarren/ThinkPhythonAssignments-/blob/main/Week_11./Week_11.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# NAME: gradebook.py
# IMPORT STATEMENTS

#FUNCTON DDEFINITIONS

# add students to the gradebook dictionary
# ask the user for students names until they type 'done'
# for each student, ask for that student's grade
# store the student name as the key and the grade as the value

# calculate the class average
# get all grade values from the dictionary
# if there are no students, return 0
# otherwise find the average and return it

#PROGRAM LOGIC

# create an empty gradebook dictionary

# call the add_students function to fill the dictionary

# print the full gradebook dictionary to test that it worked

# calculate the class average

# print a class report
# show each student's name and grade
#show the average formatted to 2 decimal places
