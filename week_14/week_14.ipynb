# %% [markdown]
# <a href="https://colab.research.google.com/github/KeiSharaWarren/ThinkPhythonAssignments-/blob/main/week_14/week_14.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# NAME libary.py

# IMPORT STATEMENTS
#none

# CLASS DEFINITONS
# Book class
# __init__ method
#   - gets the book title ans author
    - sets the book as avalible by default

# __str__ method
   - shows the book info in a readable format

# checkout method
#  - marks the book as checked out

# return_book method
#   - marks the book as returned (avalible again)

# PROGRAM LOGIC
# make two book objects
# display both books
# check out one book
# display both again to show the change
