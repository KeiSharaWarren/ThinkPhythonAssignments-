# %% [markdown]
# <a href="https://colab.research.google.com/github/KeiSharaWarren/ThinkPhythonAssignments-/blob/main/Week2/Week2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# IMPORT STATEMENTS
# (None)

# FUNCTION DEFINITIONS
# (None)

# PROGRAM LOGIC
#1.  print the total minutes in a movie. (2 * 60 + 45).
print ( "Total minutes in movies: " + str( (2 * 60)+ 45))

#2.  print the years since 1947 (2026 - 1947).
print("years since first bug: " + str (2026 - 1947))

#3.  print the total cost of 7 books (7 * 35)
print("Total cost of books:" + str(7 * 35))
# Out:
# Total minutes in movies: 165
# years since first bug: 79
# Total cost of books:245
