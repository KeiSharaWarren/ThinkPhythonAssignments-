# %% [markdown]
# <a href="https://colab.research.google.com/github/KeiSharaWarren/ThinkPhythonAssignments-/blob/main/Week_8./Week_8.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
##### Import Statements #####
# None needed

##### Function Definitons #####

def is_palindrome(word):
    normalized = word.lower()
    reversed_word = normalized[::-1]
    return normalized == reversed_word

def split_name(full_name):
    parts = full_name.split()
    return parts [0], parts [1]

    #### Program Logic ####

    #Ask the user to enter a full name
    full_name = input("Enter your full name: ")

    # Call a function to split out the first and last name
    user_first_name, user_last_name = split_name(full_name)

    #print the user's first name
    print(f"Your first name is: {user_first_name}")

    #print user's last name
    print(f"Your last name is: {user_last_name}")
