# %% [markdown]
# <a href="https://colab.research.google.com/github/KeiSharaWarren/ThinkPhythonAssignments-/blob/main/Week_7/Week_7.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#IMPORT STATEMENTS
#NONE

#FUNCTION DEFINITIONS
# 1. Define verify_pin():

#    - Create a loop that asks for a PIN until it equals 1234
#    - Return True
def verify_pin():
    pin = input("Enter PIN:")
    while pin != "1234":
         print("Incorrect PIN. Try again.")
         pin = input("Enter PIN: ")
    print("PIN Verified.")
    return True
# 2. Define withdraw(balance, amount)
# - Check if enough money exists
# - Return the new (or old) balance
def withdraw(balance, amount):
    if amount > balance:
        balance = balance - amount
        print("Insufficient funds.")
        return balance
    \else:
        print("Withdrawal successful.")
        return balance - amount

# PROGRAM LOGIC
# 1. Set current_balance to 500
# 2. Call verify_pin()
# 3. Get withdrawal amount from user input
# 4. Update current_balance by calling withdraw()
# 5. print the final balance
current_balance = 500

verify_pin()

withdrawal_amount = float(input("Enter withdrawal amount: "))

current_balance = withdraw(current_balance, withdrawal_amount)

print(f"Current Balance: ${current_balance}")
# Out:
# Enter PIN:0000
# Incorrect PIN. Try again.
# Enter PIN: 1234
# PIN Verified.
# Enter withdrawal amount: 150
# Withdrawal successful.
# Current Balance: $350.0
