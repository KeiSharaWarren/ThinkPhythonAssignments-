# %% [markdown]
# <a href="https://colab.research.google.com/github/KeiSharaWarren/ThinkPhythonAssignments-/blob/main/Week_16./Week_16.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Expense Tracker Final Project

# create empty list for expenses
expenses = []

# main loop
# show menu options
# let user get totals
# let user exit program

# each expense will be stored as a dictionary
# dictionary keys:
# category
# vendor
# amount
# date

# use append() to store dictionaries in expenses list

# filtering logic
# lopp through expenses
# compare category or vendor
# add matching amounts together
