# %% [markdown]
# <a href="https://colab.research.google.com/github/KeiSharaWarren/ThinkPhythonAssignments-/blob/main/Week10./Week10.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# NAME: roster.py

#IMPORT STATEMENTS

# FUNCTION DEFINITIONS

def add_players(roster):
    player_name = input("Enter player name (or 'quit' to stop): ")

    while player_name != "quit":
        roster.append(player_name)
        player_name = input("Enter player name (or 'quit' to stop): ")

def is_on_roster(roster, player_name):
    if player_name in roster:
        return True
    else:
        return False


# PROGRAM LOGIC

roster = []

add_players(roster)

search_name = input("Who would you like to search for?")

result = is_on_roster(roster, search_name)

if result:
    print("Result: Player found!")
else:
    print("Result: Player not found.")
# Out:
# Enter player name (or 'quit' to stop): Jordan
# Enter player name (or 'quit' to stop): Kobe
# Enter player name (or 'quit' to stop): quit
# Who would you like to search for?Jordan
# Result: Player found!
