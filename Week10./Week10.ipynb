# %% [markdown]
# <a href="https://colab.research.google.com/github/KeiSharaWarren/ThinkPhythonAssignments-/blob/main/Week10./Week10.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# NAME: roster.py

#IMPORT STATEMENTS

# FUNCTION DEFINITIONS

def add_players(rosters):
  # ask the user to enter a player name
  # while the name is not "quit"
      # add the name to the roster list
      # ask for another name

def is_on_roster(roster, player_name):
    # check if player_name is in roster
    # return True if found
    # return False if not found


# PROGRAM LOGIC

# create an empty list called roster

# call add_players function

# ask user for a name to search

# call is_on_roster function and store result

# if result is True
    # print "Player Found!"
# Else
    # print "player not found."
