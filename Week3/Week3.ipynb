# %% [markdown]
# <a href="https://colab.research.google.com/github/KeiSharaWarren/ThinkPhythonAssignments-/blob/main/Week3/Week3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Import Statements

#Function Definitions

#Program  logic
#Assign Vaules to variables: name, goal, birth_year, current_year
name = "KeiShara Warren"
goal = " become a IT Engineer"
birth_year = 2003
current_year =2026

# calculate Age
age = current_year - birth_year
#print top border
print ("=" * 25)
print("My name is " + name + " and i am" + str(age) + "years old." "my goal is" +goal)
#print bottom border
# Out:
# =========================
# My name is KeiShara Warren and i am23years old.my goal is become a IT Engineer
