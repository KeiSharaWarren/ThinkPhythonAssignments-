# %% [markdown]
# <a href="https://colab.research.google.com/github/KeiSharaWarren/ThinkPhythonAssignments-/blob/main/week_15_assigment_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
tasks = []

try:
    with open("sessions.txt", "r") as file:
        for line in file:
            tasks.append(line.srip())
except:
    pass

while True:
    print("1. Add Study Session")
    print("2. View Study Sessions")
    print("3. Exit")

    choice = input("Choose an option:")

    if choice not in ["1", "2", "3"]:
        print("Invalid option. Try again.")
        continue

        with open("sessions.txt", "a") as file:
            file.write(task + "\n")

        print("session added.")

    elif choice == "2":
        if len(tasks) ==0:
            print("No sessions yet.")
        else:
            for i in range(len(tasks)):
                print(i, "-", tasks[i])

    elif choice == "3":
        print("Goodbye!")
        break

    else:
        print("Invalid option")
# Out:
# 1. Add Study Session
# 2. View Study Sessions
# 3. Exit
# Choose an option:hello
# Invalid option. Try again.
# 1. Add Study Session
# 2. View Study Sessions
# 3. Exit
# Choose an option:invalid oprion
# Invalid option. Try again.
# 1. Add Study Session
# 2. View Study Sessions
# 3. Exit
# Choose an option:1
# Invalid option
# 1. Add Study Session
# 2. View Study Sessions
# 3. Exit
# Choose an option:2
# No sessions yet.
# 1. Add Study Session
# 2. View Study Sessions
# 3. Exit
# Choose an option:3
# Goodbye!
